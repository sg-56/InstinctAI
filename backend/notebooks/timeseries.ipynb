# %%
import pandas as pd
import os

# %%
print(os.getcwd())
# Out:
# /home/shiva/Desktop/Instinct_AI

# %%
os.listdir('data/')
# Out:
# ['cleaned_apar.csv', 'Demo Data Sales.csv']

# %%
df = pd.read_csv('data/Demo Data Sales.csv',low_memory = False)
df.head()
# Out:
#    Payment ID  Sales Date Sales Time  Outlet Id  \
# 0     2128618  01-01-2024   10:27:59      28319
# 1     2128618  01-01-2024   10:27:59      28319
# 2     2132045  04-01-2024   09:14:40      10124
# 3     2132045  04-01-2024   09:14:40      10124
# 4     2132045  04-01-2024   09:14:40      10124
#
#                            Outlet    Type City    State  \
# 0     JALARAM PROVISION - DABHODA  Others  NaN  GUJARAT
# 1     JALARAM PROVISION - DABHODA  Others  NaN  GUJARAT
# 2  MAHAKALI KIRANA STORES-ISANPUR  Others  NaN  GUJARAT
# 3  MAHAKALI KIRANA STORES-ISANPUR  Others  NaN  GUJARAT
# 4  MAHAKALI KIRANA STORES-ISANPUR  Others  NaN  GUJARAT
#
#                  Warehouse             User  ... Quantity (in Units)  \
# 0  SHREEJI TRADERS -SANODA  SHREEJI TRADERS  ...                   2
# 1  SHREEJI TRADERS -SANODA  SHREEJI TRADERS  ...                   5
# 2  SHREEJI TRADERS -SANODA  SHREEJI TRADERS  ...                  10
# ...

# %%
df.columns
# Out:
# Index(['Payment ID', 'Sales Date', 'Sales Time', 'Outlet Id', 'Outlet', 'Type',
#        'City', 'State', 'Warehouse', 'User', 'Employe Id', 'Fordate',
#        'SKU Placed', 'SkuCode', 'Category', 'Quantity (in Units)',
#        'Quantity (in Kg)', 'Quantity (in Cases)', 'Scheme', 'Discount Scheme',
#        'Variable Discount', 'Unitprice', 'Amount', 'Zone', 'Subzone'],
#       dtype='object')

# %%
df.groupby('Sales Date')['Amount'].sum().reset_index().plot(kind='line',
                                                            figsize=(15,5),
                                                            x = 'Sales Date'
                                                           )
# Out:
# <Axes: xlabel='Sales Date'>
